# %%
import requests

response = requests.get("http://127.0.0.1:9090/search/accidents")

if response.status_code == 200:
    print("yes")
    print(response.json())
else:
    print("no")
# Out:
# yes
# ...
